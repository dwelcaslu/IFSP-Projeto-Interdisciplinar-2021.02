# %%
from IPython import display
from base64 import b64decode
base64_data = "..."
display.Image(b64decode(base64_data))

# %% [markdown]
# # **Pós-graduação em Ciência de Dados** (Segundo semestre - IFSP Campinas) <br/>
#
# # **Projeto Interdisciplinar**
#
# ## Análise de dados e projeto de um regressor em computação de nuvem, usando AWS
#
#
# ### Alunos:
# #### Alexandre Freire Osorio
# #### Felipe Gomes
# #### Weld Lucas Cunha <br/>
#
# ### Professores:
# #### Bianca Pedrosa
# #### Samuel Martins <br/>

# %% [markdown]
# ## Descrição do dataset e do problema a ser resolvido

# %% [markdown]
# Os abalones são moluscos, espécie de caracóis marinhos, que vivem preferencialmente em águas frias. Pertencem ao gênero Haliotis, da família Haliotidae. Sua concha é arredondada ou ovalada, achatadas, e nela vemos uma seqüência de furos (poros), variando de 2 a 9, conforme o tipo de abalone, seguidos por uma seqüência de pequenas elevações, sem furos. Sua cor externa varia de acordo com o seu habitat natural. Já na face interior, encontra-se uma belíssima e iridescente madrepérola, podendo ser negra, azul, verde, rosa, amarela, vermelha, branca, entre outras mais, que é muito apreciada para fabricação de jóias e adornos.

# %%
base64_data = "..."
display.Image(b64decode(base64_data))

# %% [markdown]
# O objetivo do regressor projetado é prever a idade do abalone a partir de medições físicas. A idade do abalone é determinada cortando a concha através do cone, colorindo-a e contando o número de anéis em um microscópio - uma tarefa enfadonha e demorada. Outras medidas, mais fáceis de obter, são utilizadas para prever a idade. Mais informações, como padrões climáticos e localização (portanto, disponibilidade de alimentos) podem ser necessárias para resolver o problema.
#
# Dos dados originais, os exemplos com valores ausentes foram removidos (a maioria tendo o valor predito ausente) e os intervalos dos valores contínuos foram escalados para uso com uma ANN (dividindo por 200).
#
#
# Informação de Atributo:
#
# É fornecido o nome do atributo, o tipo de atributo, a unidade de medida e uma breve descrição. O número de toques é o valor a prever: seja como um valor contínuo ou como um problema de classificação.
#
# #### Referência
# https://www.kaggle.com/rodolfomendes/abalone-dataset

# %% [markdown]
# ## 1. Importando dependências

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import boto3
import seaborn as sns

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession, SQLContext

from pyspark.sql.types import *
import pyspark.sql.functions as F
from pyspark.sql.functions import udf, col

from pyspark.ml.regression import LinearRegression
from pyspark.mllib.evaluation import RegressionMetrics

from pyspark.ml.tuning import ParamGridBuilder, CrossValidator, CrossValidatorModel
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.evaluation import RegressionEvaluator

# %%
# visualização
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', 400)

from matplotlib import rcParams
sns.set(context='notebook', style='whitegrid', rc={'figure.figsize': (18,4)})
rcParams['figure.figsize'] = 18,4

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# configurando a semente aletória para repoducibilidade
rnd_seed=23
np.random.seed=rnd_seed
np.random.set_state=rnd_seed

# %% [markdown]
# ## 2. Criando a sessão Spark

# %%
spark = SparkSession.builder.master("local").appName("Abalone-Spark-Test").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ip-172-16-9-238.us-east-2.compute.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Abalone-Spark-Test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc = spark.sparkContext
sc
# Out:
# <SparkContext master=local appName=Abalone-Spark-Test>

# %%
sqlContext = SQLContext(spark.sparkContext)
sqlContext

# %% [markdown]
# ## 3. Carregando os dados a partir do S3

# %% [markdown]
# Specifying the schema when loading data into a DataFrame will give better performance than schema inference.

# %%
# define the schema, corresponding to a line in the csv data file.
schema = StructType([
    StructField("sex", StringType(), nullable=True),
    StructField("length", FloatType(), nullable=True),
    StructField("diameter", FloatType(), nullable=True),
    StructField("height", FloatType(), nullable=True),
    StructField("whole_weight", FloatType(), nullable=True),
    StructField("shucked_weight", FloatType(), nullable=True),
    StructField("viscera_weight", FloatType(), nullable=True),
    StructField("shell_weight", FloatType(), nullable=True),
    StructField("rings", IntegerType(), nullable=True)]
)

# %%
bucket='alunos'
data_key = 'felipe.gomes/abalone.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

# %%
# Load abalone data from S3:
abalone_df = spark.createDataFrame(pd.read_csv(data_location), schema=schema)
abalone_df.show()
# Out:
# +---+------+--------+------+------------+--------------+--------------+------------+-----+
# |sex|length|diameter|height|whole_weight|shucked_weight|viscera_weight|shell_weight|rings|
# +---+------+--------+------+------------+--------------+--------------+------------+-----+
# |  M| 0.455|   0.365| 0.095|       0.514|        0.2245|         0.101|        0.15|   15|
# |  M|  0.35|   0.265|  0.09|      0.2255|        0.0995|        0.0485|        0.07|    7|
# |  F|  0.53|    0.42| 0.135|       0.677|        0.2565|        0.1415|        0.21|    9|
# |  M|  0.44|   0.365| 0.125|       0.516|        0.2155|         0.114|       0.155|   10|
# |  I|  0.33|   0.255|  0.08|       0.205|        0.0895|        0.0395|       0.055|    7|
# |  I| 0.425|     0.3| 0.095|      0.3515|         0.141|        0.0775|        0.12|    8|
# |  F|  0.53|   0.415|  0.15|      0.7775|         0.237|        0.1415|        0.33|   20|
# |  F| 0.545|   0.425| 0.125|       0.768|         0.294|        0.1495|        0.26|   16|
# |  M| 0.475|    0.37| 0.125|      0.5095|        0.2165|        0.1125|       0.165|    9|
# |  F|  0.55|    0.44|  0.15|      0.8945|        0.3145|         0.151|        0.32|   19|
# |  F| 0.525|    0.38|  0.14|      0.6065|         0.194|        0.1475|        0.21|   14|
# |  M|  0.43|    0.35|  0.11|       0.406|        0.1675|         0.081|       0.135|   10|
# |  M|  0.49|    0.38| 0.135|      0.5415|        0.2175|         0.095|        0.19|   11|
# |  F| 0.535|   0.405| 0.145|      0.6845|        0.2725|         0.171|       0.205|   10|
# |  F|  0.47|   0.355|   0.1|      0.4755|        0.1675|        0.0805|       0.185|   10|
# |  M|   0.5|     0.4|  0.13|      0.6645|         0.258|         0.133|        0.24|   12|
# |  I| 0.355|    0.28| 0.085|      0.2905|         0.095|        0.0395|       0.115|    7|
# |  F|  0.44|    0.34|   0.1|       0.451|         0.188|         0.087|        0.13|   10|
# |  M| 0.365|   0.295|  0.08|      0.2555|         0.097|         0.043|         0.1|    7|
# |  M|  0.45|    0.32|   0.1|       0.381|        0.1705|         0.075|       0.115|    9|
# +---+------+--------+------+------------+--------------+--------------+------------+-----+
# only showing top 20 rows

# %% [markdown]
# ## 4. Data Exploration

# %%
# show the schema of the dataframe
abalone_df.printSchema()
# Out:
# root
#  |-- sex: string (nullable = true)
#  |-- length: float (nullable = true)
#  |-- diameter: float (nullable = true)
#  |-- height: float (nullable = true)
#  |-- whole_weight: float (nullable = true)
#  |-- shucked_weight: float (nullable = true)
#  |-- viscera_weight: float (nullable = true)
#  |-- shell_weight: float (nullable = true)
#  |-- rings: integer (nullable = true)

# %%
(abalone_df.describe().select(
                    "summary",
                    F.round("length", 4).alias("length"),
                    F.round("diameter", 4).alias("diameter"),
                    F.round("height", 4).alias("height"),
                    F.round("whole_weight", 4).alias("whole_weight"),
                    F.round("shucked_weight", 4).alias("shucked_weight"),
                    F.round("viscera_weight", 4).alias("viscera_weight"),
                    F.round("shell_weight", 4).alias("shell_weight"),
                    F.round("rings", 4).alias("rings"),
                    ).show())
# Out:
# +-------+------+--------+------+------------+--------------+--------------+------------+------+
# |summary|length|diameter|height|whole_weight|shucked_weight|viscera_weight|shell_weight| rings|
# +-------+------+--------+------+------------+--------------+--------------+------------+------+
# |  count|4177.0|  4177.0|4177.0|      4177.0|        4177.0|        4177.0|      4177.0|4177.0|
# |   mean| 0.524|  0.4079|0.1395|      0.8287|        0.3594|        0.1806|      0.2388|9.9337|
# | stddev|0.1201|  0.0992|0.0418|      0.4904|         0.222|        0.1096|      0.1392|3.2242|
# |    min| 0.075|   0.055|   0.0|       0.002|         0.001|        5.0E-4|      0.0015|   1.0|
# |    max| 0.815|    0.65|  1.13|      2.8255|         1.488|          0.76|       1.005|  29.0|
# +-------+------+--------+------+------------+--------------+--------------+------------+------+

# %%
df_pandas =  abalone_df.toPandas()

for col in df_pandas.columns:
    plt.figure(figsize=(8, 4))
    plt.title(col)
    df_pandas[col].hist(bins=10)
    plt.show()
# Out:
# Text(0.5, 1.0, 'sex')
# <AxesSubplot:title={'center':'sex'}>
# Text(0.5, 1.0, 'length')
# <AxesSubplot:title={'center':'length'}>
# Text(0.5, 1.0, 'diameter')
# <AxesSubplot:title={'center':'diameter'}>
# Text(0.5, 1.0, 'height')
# <AxesSubplot:title={'center':'height'}>
# Text(0.5, 1.0, 'whole_weight')
# <AxesSubplot:title={'center':'whole_weight'}>
# Text(0.5, 1.0, 'shucked_weight')
# <AxesSubplot:title={'center':'shucked_weight'}>
# Text(0.5, 1.0, 'viscera_weight')
# <AxesSubplot:title={'center':'viscera_weight'}>
# Text(0.5, 1.0, 'shell_weight')
# <AxesSubplot:title={'center':'shell_weight'}>
# Text(0.5, 1.0, 'rings')
# <AxesSubplot:title={'center':'rings'}>

# %% [markdown]
# ## 5. Pré-processamento

# %%
featureCols = ['length', 'diameter', 'height','whole_weight',
               'shucked_weight','viscera_weight','shell_weight']
# put features into a feature vector column
assembler = VectorAssembler(inputCols=featureCols, outputCol="features")
assembled_df = assembler.transform(abalone_df)
assembled_df
# Out:
# DataFrame[sex: string, length: float, diameter: float, height: float, whole_weight: float, shucked_weight: float, viscera_weight: float, shell_weight: float, rings: int, features: vector]

# %%
assembled_df.show(truncate=False)
# Out:
# +---+------+--------+------+------------+--------------+--------------+------------+-----+----------------------------------------------------------------------------------------------------------------------------------------------+
# |sex|length|diameter|height|whole_weight|shucked_weight|viscera_weight|shell_weight|rings|features                                                                                                                                      |
# +---+------+--------+------+------------+--------------+--------------+------------+-----+----------------------------------------------------------------------------------------------------------------------------------------------+
# |M  |0.455 |0.365   |0.095 |0.514       |0.2245        |0.101         |0.15        |15   |[0.45500001311302185,0.36500000953674316,0.0949999988079071,0.5139999985694885,0.22450000047683716,0.10100000351667404,0.15000000596046448]   |
# |M  |0.35  |0.265   |0.09  |0.2255      |0.0995        |0.0485        |0.07        |7    |[0.3499999940395355,0.26499998569488525,0.09000000357627869,0.22550000250339508,0.09950000047683716,0.048500001430511475,0.07000000029802322] |
# |F  |0.53  |0.42    |0.135 |0.677       |0.2565        |0.1415        |0.21        |9    |[0.5299999713897705,0.41999998688697815,0.13500000536441803,0.6769999861717224,0.2565000057220459,0.14149999618530273,0.20999999344348907]    |
# |M  |0.44  |0.365   |0.125 |0.516       |0.2155        |0.114         |0.155       |10   |[0.4399999976158142,0.36500000953674316,0.125,0.515999972820282,0.21549999713897705,0.11400000005960464,0.1550000011920929]                   |
# |I  |0.33  |0.255   |0.08  |0.205       |0.0895        |0.0395        |0.055       |7    |[0.33000001311302185,0.2549999952316284,0.07999999821186066,0.20499999821186066,0.08950000256299973,0.039500001817941666,0.054999999701976776]|
# |I  |0.425 |0.3     |0.095 |0.3515      |0.141         |0.0775        |0.12        |8    |[0.42500001192092896,0.30000001192092896,0.0949999988079071,0.351500004529953,0.14100000262260437,0.07750000059604645,0.11999999731779099]    |
# |F  |0.53  |0.415   |0.15  |0.7775      |0.237         |0.1415        |0.33        |20   |[0.5299999713897705,0.41499999165534973,0.15000000596046448,0.7774999737739563,0.2370000034570694,0.14149999618530273,0.33000001311302185]    |
# |F  |0.545 |0.425   |0.125 |0.768       |0.294         |0.1495        |0.26        |16   |[0.5450000166893005,0.42500001192092896,0.125,0.7680000066757202,0.2939999997615814,0.14949999749660492,0.25999999046325684]                  |
# |M  |0.475 |0.37    |0.125 |0.5095      |0.2165        |0.1125        |0.165       |9    |[0.4749999940395355,0.3700000047683716,0.125,0.5095000267028809,0.21649999916553497,0.11249999701976776,0.16500000655651093]                  |
# |F  |0.55  |0.44    |0.15  |0.8945      |0.3145        |0.151         |0.32        |19   |[0.550000011920929,0.4399999976158142,0.15000000596046448,0.8945000171661377,0.31450000405311584,0.1509999930858612,0.3199999928474426]       |
# |F  |0.525 |0.38    |0.14  |0.6065      |0.194         |0.1475        |0.21        |14   |[0.5249999761581421,0.3799999952316284,0.14000000059604645,0.6065000295639038,0.1940000057220459,0.14749999344348907,0.20999999344348907]     |
# |M  |0.43  |0.35    |0.11  |0.406       |0.1675        |0.081         |0.135       |10   |[0.4300000071525574,0.3499999940395355,0.10999999940395355,0.4059999883174896,0.16750000417232513,0.08100000023841858,0.13500000536441803]    |
# |M  |0.49  |0.38    |0.135 |0.5415      |0.2175        |0.095         |0.19        |11   |[0.49000000953674316,0.3799999952316284,0.13500000536441803,0.5414999723434448,0.2175000011920929,0.0949999988079071,0.1899999976158142]      |
# |F  |0.535 |0.405   |0.145 |0.6845      |0.2725        |0.171         |0.205       |10   |[0.5350000262260437,0.4050000011920929,0.14499999582767487,0.684499979019165,0.27250000834465027,0.17100000381469727,0.20499999821186066]     |
# |F  |0.47  |0.355   |0.1   |0.4755      |0.1675        |0.0805        |0.185       |10   |[0.4699999988079071,0.35499998927116394,0.10000000149011612,0.4754999876022339,0.16750000417232513,0.08049999922513962,0.1850000023841858]    |
# |M  |0.5   |0.4     |0.13  |0.6645      |0.258         |0.133         |0.24        |12   |[0.5,0.4000000059604645,0.12999999523162842,0.6644999980926514,0.257999986410141,0.13300000131130219,0.23999999463558197]                     |
# |I  |0.355 |0.28    |0.085 |0.2905      |0.095         |0.0395        |0.115       |7    |[0.35499998927116394,0.2800000011920929,0.08500000089406967,0.2904999852180481,0.0949999988079071,0.039500001817941666,0.11500000208616257]   |
# |F  |0.44  |0.34    |0.1   |0.451       |0.188         |0.087         |0.13        |10   |[0.4399999976158142,0.3400000035762787,0.10000000149011612,0.45100000500679016,0.18799999356269836,0.08699999749660492,0.12999999523162842]   |
# |M  |0.365 |0.295   |0.08  |0.2555      |0.097         |0.043         |0.1         |7    |[0.36500000953674316,0.29499998688697815,0.07999999821186066,0.2554999887943268,0.09700000286102295,0.0430000014603138,0.10000000149011612]   |
# |M  |0.45  |0.32    |0.1   |0.381       |0.1705        |0.075         |0.115       |9    |[0.44999998807907104,0.3199999928474426,0.10000000149011612,0.38100001215934753,0.1704999953508377,0.07500000298023224,0.11500000208616257]   |
# +---+------+--------+------+------------+--------------+--------------+------------+-----+----------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
# Initialize the `standardScaler`
standardScaler = StandardScaler(inputCol="features", outputCol="features_scaled")

# %%
# Fit the DataFrame to the scaler
prep_df = standardScaler.fit(assembled_df).transform(assembled_df)

# %%
# Inspect the result
prep_df.select("features", "features_scaled").show(10, truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------+
# |features                                                                                                                                      |features_scaled                                                                                                                          |
# +----------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------+
# |[0.45500001311302185,0.36500000953674316,0.0949999988079071,0.5139999985694885,0.22450000047683716,0.10100000351667404,0.15000000596046448]   |[3.7887332711818247,3.6779575173777133,2.2712570856645273,1.0481474452807245,1.0114300685983935,0.9214130762786045,1.0775655840557854]   |
# |[0.3499999940395355,0.26499998569488525,0.09000000357627869,0.22550000250339508,0.09950000047683716,0.048500001430511475,0.07000000029802322] |[2.914410074976496,2.670297709659031,2.15171735155266,0.4598390120477345,0.44827301600923997,0.44246073229320915,0.5028639213849467]     |
# |[0.5299999713897705,0.41999998688697815,0.13500000536441803,0.6769999861717224,0.2565000057220459,0.14149999618530273,0.20999999344348907]    |[4.413249379030336,4.232170051255845,3.22757602732899,1.3805365913148835,1.1555982976922272,1.2908905172165288,1.508591710631581]        |
# |[0.4399999976158142,0.36500000953674316,0.125,0.515999972820282,0.21549999713897705,0.11400000005960464,0.1550000011920929]                   |[3.6638298510836877,3.6779575173777133,2.988496202848747,1.0522257875130796,0.9708827457740588,1.0400107633000253,1.113484401175472]     |
# |[0.33000001311302185,0.2549999952316284,0.07999999821186066,0.20499999821186066,0.08950000256299973,0.039500001817941666,0.054999999701976776]|[2.7478725123930374,2.5695318490095436,1.9126375270724172,0.41803545721073804,0.40322046120080496,0.36035462297851834,0.3951073629793682]|
# |[0.42500001192092896,0.30000001192092896,0.0949999988079071,0.351500004529953,0.14100000262260437,0.07750000059604645,0.11999999731779099]    |[3.538926679146094,3.0229788225441414,2.2712570856645273,0.7167778848046543,0.6352411671360705,0.7070248660833747,0.862052413721369]     |
# |[0.5299999713897705,0.41499999165534973,0.15000000596046448,0.7774999737739563,0.2370000034570694,0.14149999618530273,0.33000001311302185]    |[4.413249379030336,4.1817871209311015,3.5861955859211,1.5854759017218756,1.0677457872840193,1.2908905172165288,2.370644284922728]        |
# |[0.5450000166893005,0.42500001192092896,0.125,0.7680000066757202,0.2939999997615814,0.14949999749660492,0.25999999046325684]                  |[4.538153047289017,4.282553281886542,2.988496202848747,1.5661035937997367,1.3245453866155525,1.3638737406009012,1.867780202968003]       |
# |[0.4749999940395355,0.3700000047683716,0.125,0.5095000267028809,0.21649999916553497,0.11249999701976776,0.16500000655651093]                  |[3.955270833765283,3.7283404477024567,2.988496202848747,1.0389711144851081,0.9753880113249351,1.0263263834263634,1.185322142461364]      |
# |[0.550000011920929,0.4399999976158142,0.15000000596046448,0.8945000171661377,0.31450000405311584,0.1509999930858612,0.3199999928474426]       |[4.579787437934881,4.433702072860772,3.5861955859211,1.8240620825011542,1.4169031625746367,1.3775580525036508,2.298806436590317]         |
# +----------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ### 6. Construindo um modelo baseline

# %%
# Split the data into train and test sets
train_data, test_data = prep_df.randomSplit([.8,.2], seed=rnd_seed)

# %%
train_data.show()
# Out:
# +---+------+--------+------+------------+--------------+--------------+------------+-----+--------------------+--------------------+
# |sex|length|diameter|height|whole_weight|shucked_weight|viscera_weight|shell_weight|rings|            features|     features_scaled|
# +---+------+--------+------+------------+--------------+--------------+------------+-----+--------------------+--------------------+
# |  F| 0.275|   0.195|  0.07|        0.08|         0.031|        0.0215|       0.025|    5|[0.27500000596046...|[2.28989371896744...|
# |  F|  0.29|    0.21| 0.075|       0.275|         0.113|        0.0675|       0.035|    6|[0.28999999165534...|[2.41479689090503...|
# |  F|  0.29|   0.225| 0.075|        0.14|        0.0515|        0.0235|        0.04|    5|[0.28999999165534...|[2.41479689090503...|
# |  F| 0.305|   0.225|  0.07|      0.1485|        0.0585|        0.0335|       0.045|    7|[0.30500000715255...|[2.53970031100317...|
# |  F| 0.305|    0.23|  0.08|       0.156|        0.0675|        0.0345|       0.048|    7|[0.30500000715255...|[2.53970031100317...|
# |  F| 0.325|    0.26|  0.09|      0.1915|         0.085|         0.036|       0.062|    7|[0.32499998807907...|[2.70623787358662...|
# |  F|  0.33|    0.26|  0.08|         0.2|        0.0625|          0.05|        0.07|    9|[0.33000001311302...|[2.74787251239303...|
# |  F| 0.335|    0.22|  0.07|        0.17|         0.076|        0.0365|        0.05|    6|[0.33500000834465...|[2.78950690303890...|
# |  F|  0.34|   0.255| 0.085|       0.204|         0.097|         0.021|        0.05|    6|[0.34000000357627...|[2.83114129368476...|
# |  F| 0.345|    0.25|  0.09|       0.203|         0.078|         0.059|       0.055|    6|[0.34499999880790...|[2.87277568433063...|
# |  F| 0.345|   0.255|   0.1|       0.197|         0.071|         0.051|        0.06|    9|[0.34499999880790...|[2.87277568433063...|
# |  F|  0.36|   0.265|  0.09|      0.2065|         0.078|         0.057|        0.06|    8|[0.36000001430511...|[2.99767910442876...|
# |  F|  0.36|   0.265|  0.09|      0.2165|         0.096|         0.037|      0.0735|   10|[0.36000001430511...|[2.99767910442876...|
# |  F|  0.36|    0.27|  0.09|      0.1885|        0.0845|        0.0385|       0.055|    5|[0.36000001430511...|[2.99767910442876...|
# |  F|  0.37|   0.275|  0.08|       0.227|         0.093|        0.0625|        0.07|    8|[0.37000000476837...|[3.08094788572049...|
# |  F|  0.37|   0.275| 0.085|      0.2405|         0.104|        0.0535|        0.07|    5|[0.37000000476837...|[3.08094788572049...|
# |  F|  0.37|    0.28|  0.11|      0.2305|        0.0945|        0.0465|       0.075|   10|[0.37000000476837...|[3.08094788572049...|
# |  F|  0.37|   0.285| 0.105|        0.27|        0.1125|        0.0585|      0.0835|    9|[0.37000000476837...|[3.08094788572049...|
# |  F|  0.37|    0.29| 0.115|        0.25|         0.111|         0.057|       0.075|    9|[0.37000000476837...|[3.08094788572049...|
# |  F| 0.375|    0.27| 0.135|       0.597|         0.272|         0.131|      0.1675|    7|[0.375,0.27000001...|[3.12258227636636...|
# +---+------+--------+------+------------+--------------+--------------+------------+-----+--------------------+--------------------+
# only showing top 20 rows

# %%
# Initialize `lr`
lr = (LinearRegression(featuresCol='features_scaled', labelCol="rings", predictionCol='rings_pred',
                       maxIter=10, regParam=0.3, elasticNetParam=0.8, standardization=False))

# %%
# Fit the data to the model
linearModel = lr.fit(train_data)

# %% [markdown]
# ## 7. Avaliando o modelo base

# %%
# Coefficients for the model
linearModel.coefficients
# Out:
# DenseVector([0.0, 0.078, 0.8356, 0.0, -0.104, 0.0, 1.1197])

# %%
# Intercept for the model
linearModel.intercept
# Out:
# 5.084211235021854

# %%
coeff_df = pd.DataFrame({"Feature": ["Intercept"] + featureCols, "Co-efficients": np.insert(linearModel.coefficients.toArray(), 0, linearModel.intercept)})
coeff_df = coeff_df[["Feature", "Co-efficients"]]
coeff_df
# Out:
#           Feature  Co-efficients
# 0       Intercept       5.084211
# 1          length       0.000000
# 2        diameter       0.078039
# 3          height       0.835615
# 4    whole_weight       0.000000
# 5  shucked_weight      -0.104036
# 6  viscera_weight       0.000000
# 7    shell_weight       1.119691

# %%
# Generate predictions
baseline_predictions = linearModel.transform(test_data).select("features", "rings", "rings_pred").toPandas()
baseline_predictions
# Out:
#                                                                                                                                                features  \
# 0     [0.3449999988079071, 0.25999999046325684, 0.09000000357627869, 0.2070000022649765, 0.07750000059604645, 0.04349999874830246, 0.07649999856948853]
# 1    [0.3499999940395355, 0.26499998569488525, 0.09000000357627869, 0.18549999594688416, 0.07450000196695328, 0.04149999842047691, 0.05999999865889549]
# 2     [0.3499999940395355, 0.2750000059604645, 0.06499999761581421, 0.20499999821186066, 0.07450000196695328, 0.04650000110268593, 0.07000000029802322]
# 3     [0.3700000047683716, 0.2750000059604645, 0.10000000149011612, 0.2224999964237213, 0.09300000220537186, 0.026000000536441803, 0.07999999821186066]
# 4      [0.3700000047683716, 0.29499998688697815, 0.10000000149011612, 0.2685000002384186, 0.11649999767541885, 0.0560000017285347, 0.08349999785423279]
# ..                                                                                                                                                  ...
# 791         [0.7200000286102295, 0.574999988079071, 0.23000000417232513, 2.2695000171661377, 0.8834999799728394, 0.398499995470047, 0.6650000214576721]
# 792        [0.7250000238418579, 0.5049999952316284, 0.1850000023841858, 1.9780000448226929, 1.0260000228881836, 0.4255000054836273, 0.4505000114440918]
# 793         [0.7250000238418579, 0.5699999928474426, 0.1899999976158142, 2.549999952316284, 1.0705000162124634, 0.4830000102519989, 0.7250000238418579]
# 794                      [0.75, 0.550000011920929, 0.18000000715255737, 1.8930000066757202, 0.9419999718666077, 0.3970000147819519, 0.4449999928474426]
# 795        [0.7699999809265137, 0.6050000190734863, 0.17499999701976776, 2.05049991607666, 0.8004999756813049, 0.5260000228881836, 0.35499998927116394]
#
#      rings  rings_pred
# 0       10    7.665683
# 1        7    7.538302
# 2       10    7.127155
# 3        8    7.898145
# 4        7    7.931010
# ..     ...         ...
# 791     16   15.066171
# 792     12   12.319978
# 793     14   14.658093
# 794     11   12.250606
# 795     11   11.536365
#
# [796 rows x 3 columns]

# %%
ybase_true = baseline_predictions["rings"].values
ybase_pred = baseline_predictions["rings_pred"].values

# %%
def get_model_metrics(y_true, y_pred, model_name=''):
    model_metrics = {"mse": mean_squared_error(y_true, y_pred),
                     "mae": mean_absolute_error(y_true, y_pred),
                     "rmse": mean_squared_error(y_true, y_pred)**(1/2),
                     "r2": r2_score(y_true, y_pred),
                     "model": model_name,
                    }
    return model_metrics

baseline_metrics = get_model_metrics(ybase_true, ybase_pred, "baseline")
baseline_metrics
# Out:
# {'mse': 5.659655762010356,
#  'mae': 1.7321721401236,
#  'rmse': 2.379003102564256,
#  'r2': 0.3619076381253872,
#  'model': 'baseline'}

# %% [markdown]
# ## 8. Modelos avançados

# %%
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.regression import LinearRegression, RandomForestRegressor
from pyspark.ml import Pipeline
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

# %%
numFolds = 5

# %%
# Data Preparation
assembled_df = assembled_df.withColumnRenamed("rings", "label")

# Split the data into train and test sets
train_data, test_data = assembled_df.randomSplit([.8,.2], seed=rnd_seed)

standardScaler = StandardScaler(inputCol="features", outputCol="features_scaled")

# %%
# Linear Regression
lr = LinearRegression(maxIter=30)

pipeline = Pipeline(stages=[standardScaler, lr])

# We use a ParamGridBuilder to construct a grid of parameters to search over.
# TrainValidationSplit will try all combinations of values and determine best model using
# the evaluator.
paramGrid = ParamGridBuilder()\
    .addGrid(lr.regParam, [0.5, 0.1, 0.05, 0.01, 0.005, 0.001, 0.0])\
    .addGrid(lr.fitIntercept, [False, True])\
    .addGrid(lr.elasticNetParam, [0.0, 0.01,0.05, 0.1, 0.5, 0.8, 1.0])\
    .build()

crossval = CrossValidator(estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=RegressionEvaluator(),
                          numFolds=numFolds)

# Run cross-validation, and choose the best set of parameters.
LRModel = crossval.fit(train_data)

# %%
# Random Forest
rf = RandomForestRegressor()
pipeline = Pipeline(stages=[standardScaler, rf])

# We use a ParamGridBuilder to construct a grid of parameters to search over.
# TrainValidationSplit will try all combinations of values and determine best model using
# the evaluator.
paramGrid = ParamGridBuilder()\
    .addGrid(rf.numTrees, [1,2,3,5,10,15,20])\
    .addGrid(rf.maxDepth, [1,2,3,5,10])\
    .addGrid(rf.minInstancesPerNode, [1,2,3,5,10])\
    .build()

crossval = CrossValidator(estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=RegressionEvaluator(),
                          numFolds=numFolds)

# Run cross-validation, and choose the best set of parameters.
RFModel = crossval.fit(train_data)

# %% [markdown]
# ## 8. Avaliação do(s) modelo(s) avançados(s)

# %%
# Linear Regression model
lr_predictions = LRModel.bestModel.transform(test_data).select("features", "label", "prediction").toPandas()
lr_predictions
# Out:
#                                                                                                                                                features  \
# 0     [0.3449999988079071, 0.25999999046325684, 0.09000000357627869, 0.2070000022649765, 0.07750000059604645, 0.04349999874830246, 0.07649999856948853]
# 1    [0.3499999940395355, 0.26499998569488525, 0.09000000357627869, 0.18549999594688416, 0.07450000196695328, 0.04149999842047691, 0.05999999865889549]
# 2     [0.3499999940395355, 0.2750000059604645, 0.06499999761581421, 0.20499999821186066, 0.07450000196695328, 0.04650000110268593, 0.07000000029802322]
# 3     [0.3700000047683716, 0.2750000059604645, 0.10000000149011612, 0.2224999964237213, 0.09300000220537186, 0.026000000536441803, 0.07999999821186066]
# 4      [0.3700000047683716, 0.29499998688697815, 0.10000000149011612, 0.2685000002384186, 0.11649999767541885, 0.0560000017285347, 0.08349999785423279]
# ..                                                                                                                                                  ...
# 791         [0.7200000286102295, 0.574999988079071, 0.23000000417232513, 2.2695000171661377, 0.8834999799728394, 0.398499995470047, 0.6650000214576721]
# 792        [0.7250000238418579, 0.5049999952316284, 0.1850000023841858, 1.9780000448226929, 1.0260000228881836, 0.4255000054836273, 0.4505000114440918]
# 793         [0.7250000238418579, 0.5699999928474426, 0.1899999976158142, 2.549999952316284, 1.0705000162124634, 0.4830000102519989, 0.7250000238418579]
# 794                      [0.75, 0.550000011920929, 0.18000000715255737, 1.8930000066757202, 0.9419999718666077, 0.3970000147819519, 0.4449999928474426]
# 795        [0.7699999809265137, 0.6050000190734863, 0.17499999701976776, 2.05049991607666, 0.8004999756813049, 0.5260000228881836, 0.35499998927116394]
#
#      label  prediction
# 0       10    7.546462
# 1        7    7.341366
# 2       10    7.111793
# 3        8    7.959710
# 4        7    7.826830
# ..     ...         ...
# 791     16   17.437849
# 792     12    8.021315
# 793     14   14.887519
# 794     11    9.557609
# 795     11   12.095257
#
# [796 rows x 3 columns]

# %%
ylr_true = lr_predictions["label"].values
ylr_pred = lr_predictions["prediction"].values

lr_metrics = get_model_metrics(ylr_true, ylr_pred, "LR model")
lr_metrics
# Out:
# {'mse': 4.800512382530324,
#  'mae': 1.5670000522987002,
#  'rmse': 2.191007161679378,
#  'r2': 0.45877091943679693,
#  'model': 'LR model'}

# %%
# Random Forest model
rf_predictions = RFModel.bestModel.transform(test_data).select("features", "label", "prediction").toPandas()
rf_predictions
# Out:
#                                                                                                                                                features  \
# 0     [0.3449999988079071, 0.25999999046325684, 0.09000000357627869, 0.2070000022649765, 0.07750000059604645, 0.04349999874830246, 0.07649999856948853]
# 1    [0.3499999940395355, 0.26499998569488525, 0.09000000357627869, 0.18549999594688416, 0.07450000196695328, 0.04149999842047691, 0.05999999865889549]
# 2     [0.3499999940395355, 0.2750000059604645, 0.06499999761581421, 0.20499999821186066, 0.07450000196695328, 0.04650000110268593, 0.07000000029802322]
# 3     [0.3700000047683716, 0.2750000059604645, 0.10000000149011612, 0.2224999964237213, 0.09300000220537186, 0.026000000536441803, 0.07999999821186066]
# 4      [0.3700000047683716, 0.29499998688697815, 0.10000000149011612, 0.2685000002384186, 0.11649999767541885, 0.0560000017285347, 0.08349999785423279]
# ..                                                                                                                                                  ...
# 791         [0.7200000286102295, 0.574999988079071, 0.23000000417232513, 2.2695000171661377, 0.8834999799728394, 0.398499995470047, 0.6650000214576721]
# 792        [0.7250000238418579, 0.5049999952316284, 0.1850000023841858, 1.9780000448226929, 1.0260000228881836, 0.4255000054836273, 0.4505000114440918]
# 793         [0.7250000238418579, 0.5699999928474426, 0.1899999976158142, 2.549999952316284, 1.0705000162124634, 0.4830000102519989, 0.7250000238418579]
# 794                      [0.75, 0.550000011920929, 0.18000000715255737, 1.8930000066757202, 0.9419999718666077, 0.3970000147819519, 0.4449999928474426]
# 795        [0.7699999809265137, 0.6050000190734863, 0.17499999701976776, 2.05049991607666, 0.8004999756813049, 0.5260000228881836, 0.35499998927116394]
#
#      label  prediction
# 0       10    7.805500
# 1        7    7.081878
# 2       10    7.334644
# 3        8    8.065313
# 4        7    7.978876
# ..     ...         ...
# 791     16   12.961006
# 792     12   10.701015
# 793     14   12.710703
# 794     11   10.724439
# 795     11   11.962876
#
# [796 rows x 3 columns]

# %%
yrf_true = rf_predictions["label"].values
yrf_pred = rf_predictions["prediction"].values

rf_metrics = get_model_metrics(yrf_true, yrf_pred, "RF model")
rf_metrics
# Out:
# {'mse': 4.078504301781247,
#  'mae': 1.494928164402399,
#  'rmse': 2.019530713255247,
#  'r2': 0.5401730154141127,
#  'model': 'RF model'}

# %% [markdown]
# ## 9. Conclusão

# %%
# Comparando todas as métricas
all_metrics = pd.DataFrame([baseline_metrics, lr_metrics, rf_metrics])
all_metrics
# Out:
#         mse       mae      rmse        r2     model
# 0  5.659656  1.732172  2.379003  0.361908  baseline
# 1  4.800512  1.567000  2.191007  0.458771  LR model
# 2  4.078504  1.494928  2.019531  0.540173  RF model

# %%
def plot_model_comparison(y_true, y_pred_list, y_labels_list):
    x_array = np.arange(0, len(y_true), 1)
    
    plt.figure(figsize=(14, 10))
    plt.subplot(2,1,1)
    plt.title("sample predictions")
    plt.plot(x_array, ybase_true, color='gray',label='True values', alpha=0.75, linewidth=2,  zorder=2)
    for y_array,label in zip(y_pred_list, y_labels_list):
        plt.scatter(x_array, y_array, label=label, alpha=0.75, zorder=0)
    plt.xlim([x_array[0], x_array[-1]])
    plt.legend(loc='best')

    plt.subplot(2,1,2)
    plt.title("predictions distribution")
    sns.kdeplot(data=ybase_true, color='gray',label='True values', alpha=0.75, linewidth=4, zorder=2)
    for y_array,label in zip(y_pred_list, y_labels_list):
        plt.hist(y_array, label=label, alpha=0.75, bins=30, density=True, zorder=0)
    plt.legend(loc='best')

    plt.tight_layout()
    plt.show()
    
    
plot_model_comparison(ybase_true, [ybase_pred, ylr_pred, yrf_pred], ['Baseline', "LR model", "RF model"])

# %%
# Stop the spark session
spark.stop()
